# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("testdata2d_004.txt")

# %%
with plt.style.context("ggplot"):
    fig, ax = plt.subplots()
    ax.plot(data[:, 0])
    ax.plot(data[:, 1])
    plt.show()
